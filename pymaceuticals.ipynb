# %% [markdown]
# ## Summary
#
# The data includes study results for mice, measuring various features including general demographics (sex, age, weight) and test features (Drug Regimen, Tumor Volume, Number of Metastatic sites).  There were 249 mice in the original merged data.  Data was removed for one mouse as the data appeared to be unreliable.
#
# ## Observations and Insights
# After removing the data that appeared unreliable, the following insights were observed on this dataset:
#
# * Of the nine drug regimens (and one placebo) included in the test, Ramicane had the lowest mean and median tumor volume, and lowest standard deviation, implying that it was potentially the most effective. The highest mean and median tumor volumes were observed with the Ketapril treatment, indicating that this treatment was potentially even less effective than the placebo.
#
# * Of the mice included in the study, 51% were male and 49% were female, a nearly even distribution.
#
# * Looking at a subset of the treatment regimens, Capomulin and Ramicane had similar outcomes, with Ramicane reflecting the lowest tumor volumes, with no outliers. Infubinol and Ceftamin had higher tumor volumes, though Infubinol results reflect one outlier in the range of the Ramicane median.
#
# * Looking further at the Capomulin data for a single mouse, it appears that the treatment is associated with an increase in tumor volume initially, but the tumor volume decreases over time.  The data was taken over 45 days.  The tumor volume increased on average over days 35-45, though was significantly reduced from the start of the treatment.
#
# * As might be expected, there is a strong positive relationship between tumor size and a mouse's weight (in grams).  The correlation between the mouse weight and average tumor volume is 0.84.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
import random

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df=pd.merge(mouse_metadata,study_results, on=['Mouse ID'])
# Display the data table for preview
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
len(combined_df['Mouse ID'].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combined_df[combined_df.duplicated(subset=['Mouse ID','Timepoint'])]

duplicate_record=combined_df[combined_df.duplicated(subset=['Mouse ID','Timepoint'])]

duplicate_id=duplicate_record['Mouse ID']

duplicate_id
# Out:
# 909    g989
# 911    g989
# 913    g989
# 915    g989
# 917    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse=combined_df.loc[combined_df['Mouse ID'].isin (duplicate_id)]

duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df=combined_df.drop(duplicate_mouse.index)

clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.

len(clean_df['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# Mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
regimen=clean_df.groupby(['Drug Regimen'])
tumor_mean=regimen['Tumor Volume (mm3)'].mean()
tumor_median=regimen['Tumor Volume (mm3)'].median()
tumor_variance=regimen['Tumor Volume (mm3)'].var()
tumor_std=regimen['Tumor Volume (mm3)'].std()
tumor_sem=regimen['Tumor Volume (mm3)'].sem()

summary_stats=pd.DataFrame({"Mean Tumor Volume": tumor_mean,
                           "Median Tumor Volume": tumor_median,
                           "Variance of Tumor Volume": tumor_variance,
                           "Std. Dev. of Tumor Volume": tumor_std,
                           "Std. Err. of Tumor Volume": tumor_sem})

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809
# Ceftamin              52.591172            51.776157
# Infubinol             52.884795            51.820584
# Ketapril              55.235638            53.698743
# Naftisol              54.331565            52.509285
# Placebo               54.033581            52.288934
# Propriva              52.320930            50.446266
# Ramicane              40.216745            40.673236
# Stelasyn              54.233149            52.431737
# Zoniferol             53.236507            51.818479
#
#               Variance of Tumor Volume  Std. Dev. of Tumor Volume  \
# Drug Regimen
# Capomulin                    24.947764                   4.994774
# Ceftamin                     39.290177                   6.268188
# Infubinol                    43.128684                   6.567243
# Ketapril                     68.553577                   8.279709
# ...

# %%
# Using the aggregation method, produce the same summary statistics in a single line
summary_stats_agg=clean_df.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)':['mean', 'median','var','std','sem']})

summary_stats_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

count_regimen=clean_df.groupby(['Drug Regimen'])['Drug Regimen'].count().sort_values(ascending=False)

count_chart=count_regimen.plot.bar(rot=90)

count_chart.set_xlabel("Drug Regimen")
count_chart.set_ylabel("Number of Measurements")
count_chart.set_title("Number of Measurements Taken on Drug Regimen")
# Out:
# Text(0.5, 1.0, 'Number of Measurements Taken on Drug Regimen')

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.

x_axis = np.arange(len(count_regimen))
y_axis=count_regimen
plt.bar(x_axis, y_axis, width=0.5, color = 'b', alpha=0.5, align="center", tick_label=count_regimen.index.values)
plt.xticks(rotation=90)
plt.title("Number of Measurements Taken on Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements Taken")
# Out:
# Text(0, 0.5, 'Number of Measurements Taken')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
mouse_gender=clean_df.groupby(['Sex'], sort=False)['Sex'].count().sort_values(ascending=False)

mouse_pie=mouse_gender.plot(kind='pie', autopct='%1.1f%%')

plt.title("Distribution of Mice by Sex")
# Out:
# Text(0.5, 1.0, 'Distribution of Mice by Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# The colors of each section of the pie chart
colors = ["tab:blue", "tab:orange"]

labels=mouse_gender.index

plt.pie(mouse_gender, labels=labels, colors=colors,autopct="%1.1f%%")

plt.ylabel("Sex")
plt.title ("Distribution of Mice by Sex")
# Out:
# Text(0.5, 1.0, 'Distribution of Mice by Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoint=clean_df.groupby(['Mouse ID'])['Timepoint'].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_df=pd.merge(max_timepoint, clean_df, on=['Mouse ID', 'Timepoint'])

new_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_regimens=['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

treatment_df = new_df.loc[(new_df['Drug Regimen'].isin(treatment_regimens))]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list=[]

# Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatment_regimens:
    
    treatment_data=treatment_df.loc[treatment_df['Drug Regimen']==treatment]
    tumor_vol=treatment_data['Tumor Volume (mm3)']
    
    # add subset 
    tumor_vol_list.append(tumor_vol)

    # Calculate the IQR and quantitatively determine if there are any potential outliers. 
    quartiles = tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    lower_bound = lowerq - (1.5*iqr)
    lower_bound = lower_bound
    upper_bound = upperq + (1.5*iqr)

    # Determine outliers using upper and lower bounds
    upper_outlier=tumor_vol[tumor_vol>upper_bound]
    lower_outlier=tumor_vol[tumor_vol<lower_bound]
    print(f"For {treatment}, values below{lower_bound: .2f} or above{upper_bound: .2f} could be outliers. {treatment}'s potential outliers: {upper_outlier.values} and {lower_outlier.values}.")
# Out:
# For Capomulin, values below 20.70 or above 51.83 could be outliers. Capomulin's potential outliers: [] and [].
# For Ramicane, values below 17.91 or above 54.31 could be outliers. Ramicane's potential outliers: [] and [].
# For Infubinol, values below 36.83 or above 82.74 could be outliers. Infubinol's potential outliers: [] and [36.3213458].
# For Ceftamin, values below 25.36 or above 87.67 could be outliers. Ceftamin's potential outliers: [] and [].

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volume by Treatment Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.set_xlabel('Treatment Regimen')
flierprops_style = dict(marker='o', markerfacecolor='blue', markersize=6)
medianprops_style = dict(linestyle='-', linewidth=2, color='purple')
ax1.boxplot(tumor_vol_list, labels=treatment_regimens, flierprops=flierprops_style, medianprops=medianprops_style)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Using all timepoints available, select one mouse.
capomulin_df=clean_df=clean_df.loc[clean_df['Drug Regimen']=='Capomulin']
available_mice =capomulin_df['Mouse ID'].unique()

print(f'Available mice:')
print(available_mice) 

#Selecting a mouse in Capomulin dataframe (from available mice list)
selected_mouse_name=available_mice[12]

selected_mouse=capomulin_df.loc[capomulin_df['Mouse ID']==selected_mouse_name]
selected_mouse

x_axis=selected_mouse['Timepoint']
y_axis=selected_mouse['Tumor Volume (mm3)']
plt.plot(x_axis, y_axis, color='blue', marker='o', linewidth=2, markersize=4)
plt.title(f"Effectiveness of Capomulin Treatment for Mouse {selected_mouse_name}")
plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")

plt.xlabel
plt.show()
# Out:
# Available mice:
# ['s185' 'x401' 'm601' 'f966' 'u364' 'y793' 'r554' 'm957' 't565' 'i738'
#  'w914' 'g288' 'l897' 'b742' 'b128' 'j246' 'j119' 'w150' 'v923' 'g316'
#  's710' 'l509' 'r944' 'i557' 'r157']

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
avg_tumor_volume=capomulin_df.groupby(['Mouse ID'])['Tumor Volume (mm3)'].mean()
mouse_weight=capomulin_df.groupby('Mouse ID')['Weight (g)'].mean()

plt.scatter(mouse_weight, avg_tumor_volume, marker="o", facecolors="royalblue", edgecolors="black", alpha=0.75)

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen (all mice)

#Regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(mouse_weight, avg_tumor_volume)
regress_values = mouse_weight * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Graph datapoints with regression line

plt.scatter(mouse_weight, avg_tumor_volume, marker="o", facecolors="royalblue", edgecolors="black", alpha=0.75)
plt.plot(mouse_weight,regress_values,"red")
plt.annotate(line_eq,(20,36),fontsize=15,color="red")
plt.title("Relationship Between Mouse Weight and Average Tumor Volume")
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

#Correlation Coefficient:
correlation = st.pearsonr(mouse_weight,avg_tumor_volume)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}.")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84.
